# %% [markdown]
# # 🧠 Treinamento de Modelos CNN - Detecção de Pneumonia
#
# Neste notebook, vamos treinar diferentes arquiteturas de redes neurais convolucionais (CNN) para detectar pneumonia em radiografias de tórax.
#
# ## 📋 Objetivos:
# 1. Preparar dados com data augmentation
# 2. Treinar modelo CNN simples (baseline)
# 3. Treinar modelos com Transfer Learning (VGG16, ResNet50)
# 4. Avaliar e comparar todos os modelos
# 5. Interpretar resultados
#
# ---

# %% [markdown]
# ## 📚 1. Importar Bibliotecas e Módulos

# %% [markdown]
# ## ⚙️ Configuração de GPU (Importante!)
#
# **Status da GPU:**
# - Este notebook pode rodar com ou sem GPU
# - **Com GPU**: Treinamento 10-15x mais rápido (~30-60 minutos total)
# - **Sem GPU (CPU)**: Treinamento mais lento (~2-4 horas total)
#
# **Ambiente Recomendado (seguindo documentação oficial TensorFlow):**
# - **Python 3.9**
# - **TensorFlow 2.10**
# - **CUDA 11.2** + **cuDNN 8.1** (instalados via conda)
#
# **Se você tem GPU NVIDIA mas ela não está sendo detectada:**
#
# Siga a documentação oficial: https://www.tensorflow.org/install/pip?hl=pt-br#windows-native
#
# Usando Conda (recomendado):
# ```bash
# conda create -n venv python=3.9 -y
# conda activate venv
# conda install -c conda-forge cudatoolkit=11.2 cudnn=8.1.0 -y
# pip install "tensorflow<2.11"
# ```
#
# **Ajustes para rodar sem GPU:**
# ```python
# # Reduzir batch size e epochs se for usar CPU
# BATCH_SIZE = 16  # ao invés de 32
# EPOCHS = 10      # ao invés de 20
# ```

# %%
# Adicionar diretório src ao path
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))

# Importar módulos customizados
from src.preprocessing import (
    create_data_generators, 
    analyze_dataset_distribution,
    get_class_weights,
    visualize_samples
)
from src.models import (
    create_simple_cnn,
    create_vgg16_transfer,
    create_resnet50_transfer,
    print_model_summary
)
from src.evaluation import (
    evaluate_model,
    plot_confusion_matrix,
    plot_roc_curve,
    plot_training_history,
    compare_models_results
)

# Bibliotecas padrão
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# TensorFlow/Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# Configurações
import warnings
warnings.filterwarnings('ignore')

# Seed para reprodutibilidade
np.random.seed(42)
tf.random.set_seed(42)

print("✅ Bibliotecas importadas!")
print(f"🔧 TensorFlow version: {tf.__version__}")

# Verificar GPU
gpus = tf.config.list_physical_devices('GPU')
gpu_available = len(gpus) > 0

if gpu_available:
    print(f"🎮 GPU disponível: SIM - {len(gpus)} dispositivo(s)")
    for i, gpu in enumerate(gpus):
        print(f"   GPU {i}: {gpu}")
    print("⚡ Treinamento será RÁPIDO!")
else:
    print("💻 GPU disponível: NÃO - Usando CPU")
    print("⏳ Treinamento será mais lento (considere reduzir BATCH_SIZE e EPOCHS)")
    print("\n💡 Para habilitar GPU:")
    print("   1. Verifique se tem NVIDIA GPU")
    print("   2. Instale CUDA 12.6 (não 13.0): https://developer.nvidia.com/cuda-12-6-0-download-archive")
    print("   3. Instale cuDNN 9.x para CUDA 12.6")
    print("   4. Reinicie o notebook")
# Out:
# ✅ Bibliotecas importadas!
# 🔧 TensorFlow version: 2.10.1
# 🎮 GPU disponível: SIM - 1 dispositivo(s)
#    GPU 0: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# ⚡ Treinamento será RÁPIDO!

# %% [markdown]
# ## 📂 2. Configurar Caminhos e Parâmetros

# %%
# Caminhos
BASE_DIR = Path('..')
DATA_DIR = BASE_DIR / 'data' / 'chest_xray'
RESULTS_DIR = BASE_DIR / 'results'
MODELS_DIR = RESULTS_DIR / 'modelos'
GRAFICOS_DIR = RESULTS_DIR / 'graficos'

# Criar diretórios se não existirem
MODELS_DIR.mkdir(parents=True, exist_ok=True)
GRAFICOS_DIR.mkdir(parents=True, exist_ok=True)

# Parâmetros de treinamento
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 20  # Ajuste conforme necessário
PATIENCE = 5  # Para early stopping

print("✅ Configurações definidas!")
print(f"📁 Dados: {DATA_DIR}")
print(f"💾 Modelos serão salvos em: {MODELS_DIR}")
print(f"📊 Gráficos serão salvos em: {GRAFICOS_DIR}")
# Out:
# ✅ Configurações definidas!
# 📁 Dados: ..\data\chest_xray
# 💾 Modelos serão salvos em: ..\results\modelos
# 📊 Gráficos serão salvos em: ..\results\graficos

# %% [markdown]
# ## 📊 3. Análise e Preparação dos Dados

# %%
# Analisar distribuição do dataset
print("📊 Análise do dataset:\n")
stats = analyze_dataset_distribution(DATA_DIR)
# Out:
# 📊 Análise do dataset:
#
# 📊 Distribuição do Dataset
#
# ============================================================
#
# TRAIN:
#   Normal:     1341 (25.7%)
#   Pneumonia:  3875 (74.3%)
#   Total:      5216
#
# TEST:
#   Normal:      234 (37.5%)
#   Pneumonia:   390 (62.5%)
#   Total:       624
#
# VAL:
#   Normal:        8 (50.0%)
#   Pneumonia:     8 (50.0%)
#   Total:        16
#
# ============================================================

# %% [markdown]
# ### 🔄 Criar Geradores de Dados

# %%
# Criar geradores COM data augmentation
print("\n🔄 Criando geradores de dados com Data Augmentation...\n")

train_generator, val_generator, test_generator = create_data_generators(
    DATA_DIR,
    img_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    augmentation=True,
    validation_split=0.2
)

print(f"✅ Gerador de treino: {train_generator.samples} amostras")
print(f"✅ Gerador de validação: {val_generator.samples} amostras")
print(f"✅ Gerador de teste: {test_generator.samples} amostras")

# Verificar classes
print(f"\n🏷️ Classes: {train_generator.class_indices}")
# Out:
# 🔄 Criando geradores de dados com Data Augmentation...
#
# Found 4173 images belonging to 2 classes.
# Found 1043 images belonging to 2 classes.
# Found 1043 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# ✅ Gerador de treino: 4173 amostras
# ✅ Gerador de validação: 1043 amostras
# ✅ Gerador de teste: 624 amostras
#
# 🏷️ Classes: {'NORMAL': 0, 'PNEUMONIA': 1}
# Found 624 images belonging to 2 classes.
# ✅ Gerador de treino: 4173 amostras
# ✅ Gerador de validação: 1043 amostras
# ✅ Gerador de teste: 624 amostras
#
# 🏷️ Classes: {'NORMAL': 0, 'PNEUMONIA': 1}

# %% [markdown]
# ### 📸 Visualizar Amostras com Augmentation

# %%
# Visualizar algumas amostras
print("\n📸 Visualizando amostras de treino (com data augmentation)...\n")
visualize_samples(train_generator, num_samples=9)
# Out:
# 📸 Visualizando amostras de treino (com data augmentation)...
# 📸 Visualizando amostras de treino (com data augmentation)...

# %% [markdown]
# ### ⚖️ Calcular Pesos das Classes

# %%
# Calcular class weights para lidar com desbalanceamento
class_weights = get_class_weights(train_generator)

print("\n💡 Esses pesos ajudam o modelo a dar mais atenção à classe minoritária!")
# Out:
# ⚖️ Pesos das Classes (para balanceamento):
#   Classe 0 (NORMAL):    1.94
#   Classe 1 (PNEUMONIA): 0.67
#
# 💡 Esses pesos ajudam o modelo a dar mais atenção à classe minoritária!

# %% [markdown]
# ## 🎛️ 4. Definir Callbacks

# %%
def get_callbacks(model_name):
    """Retorna callbacks para treinamento."""
    
    callbacks = [
        # Early Stopping: para se não houver melhora
        EarlyStopping(
            monitor='val_loss',
            patience=PATIENCE,
            verbose=1,
            restore_best_weights=True
        ),
        
        # Model Checkpoint: salva melhor modelo
        ModelCheckpoint(
            filepath=str(MODELS_DIR / f'{model_name}_best.h5'),
            monitor='val_loss',
            save_best_only=True,
            verbose=1
        ),
        
        # Reduce Learning Rate: reduz LR quando estagnado
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=3,
            verbose=1,
            min_lr=1e-7
        )
    ]
    
    return callbacks

print("✅ Callbacks configurados!")
print("   - Early Stopping (paciência: 5 épocas)")
print("   - Model Checkpoint (salva melhor modelo)")
print("   - Reduce LR on Plateau (reduz learning rate)")
# Out:
# ✅ Callbacks configurados!
#    - Early Stopping (paciência: 5 épocas)
#    - Model Checkpoint (salva melhor modelo)
#    - Reduce LR on Plateau (reduz learning rate)

# %% [markdown]
# ---
# # 🚀 TREINAMENTO DOS MODELOS
# ---

# %% [markdown]
# ## 1️⃣ Modelo 1: CNN Simples (Baseline)
#
# Este é nosso modelo baseline - uma CNN simples criada do zero. Serve para termos uma referência de desempenho.

# %%
print("="*70)
print("🔧 MODELO 1: CNN SIMPLES (BASELINE)")
print("="*70)

# Criar modelo
model_cnn = create_simple_cnn(input_shape=(*IMG_SIZE, 3), dropout_rate=0.5)

# Ver arquitetura
print_model_summary(model_cnn, "CNN Simples")
# Out:
# ======================================================================
# 🔧 MODELO 1: CNN SIMPLES (BASELINE)
# ======================================================================
#
# ============================================================
# 📊 Resumo do CNN Simples
# ============================================================
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  batch_normalization (BatchN  (None, 111, 111, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 54, 54, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 26, 26, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       147584
#
# ============================================================
# 📊 Resumo do CNN Simples
# ============================================================
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  batch_normalization (BatchN  (None, 111, 111, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 54, 54, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 26, 26, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 512)               9437696
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 9,811,521
# Trainable params: 9,810,817
# Non-trainable params: 704
# _________________________________________________________________
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 512)               9437696
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 9,811,521
# Trainable params: 9,810,817
# Non-trainable params: 704
# _________________________________________________________________
#
# ============================================================
# Total de parâmetros: 9,811,521
# Parâmetros treináveis: 9,810,817
# Parâmetros não-treináveis: 704
# ============================================================
#
#
# ============================================================
# Total de parâmetros: 9,811,521
# Parâmetros treináveis: 9,810,817
# Parâmetros não-treináveis: 704
# ============================================================

# %%
# Treinar modelo
print("\n🚀 Iniciando treinamento da CNN Simples...\n")

history_cnn = model_cnn.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    class_weight=class_weights,
    callbacks=get_callbacks('cnn_simple'),
    verbose=1
)

print("\n✅ Treinamento da CNN Simples concluído!")
# Out:
# 🚀 Iniciando treinamento da CNN Simples...
#
# Epoch 1/20
# Epoch 1/20
# 131/131 [==============================] - ETA: 0s - loss: 1.2289 - accuracy: 0.8347 - precision: 0.9316 - recall: 0.8390 - auc: 0.8868
# Epoch 1: val_loss improved from inf to 11.36341, saving model to ..\results\modelos\cnn_simple_best.h5
#
# Epoch 1: val_loss improved from inf to 11.36341, saving model to ..\results\modelos\cnn_simple_best.h5
# 131/131 [==============================] - 587s 479ms/step - loss: 1.2289 - accuracy: 0.8347 - precision: 0.9316 - recall: 0.8390 - auc: 0.8868 - val_loss: 11.3634 - val_accuracy: 0.7430 - val_precision: 0.7430 - val_recall: 1.0000 - val_auc: 0.5000 - lr: 0.0010
# Epoch 2/20
# 131/131 [==============================] - 587s 479ms/step - loss: 1.2289 - accuracy: 0.8347 - precision: 0.9316 - recall: 0.8390 - auc: 0.8868 - val_loss: 11.3634 - val_accuracy: 0.7430 - val_precision: 0.7430 - val_recall: 1.0000 - val_auc: 0.5000 - lr: 0.0010
# Epoch 2/20
# 131/131 [==============================] - ETA: 0s - loss: 0.6019 - accuracy: 0.8747 - precision: 0.9542 - recall: 0.8732 - auc: 0.9315
# Epoch 2: val_loss improved from 11.36341 to 9.18921, saving model to ..\results\modelos\cnn_simple_best.h5
#
# Epoch 2: val_loss improved from 11.36341 to 9.18921, saving model to ..\results\modelos\cnn_simple_best.h5
# 131/131 [==============================] - 47s 362ms/step - loss: 0.6019 - accuracy: 0.8747 - precision: 0.9542 - recall: 0.8732 - auc: 0.9315 - val_loss: 9.1892 - val_accuracy: 0.7430 - val_precision: 0.7430 - val_recall: 1.0000 - val_auc: 0.5000 - lr: 0.0010
# Epoch 3/20
# 131/131 [==============================] - 47s 362ms/step - loss: 0.6019 - accuracy: 0.8747 - precision: 0.9542 - recall: 0.8732 - auc: 0.9315 - val_loss: 9.1892 - val_accuracy: 0.7430 - val_precision: 0.7430 - val_recall: 1.0000 - val_auc: 0.5000 - lr: 0.0010
# Epoch 3/20
# 131/131 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8826 - precision: 0.9624 - recall: 0.8761 - auc: 0.9448
# Epoch 3: val_loss improved from 9.18921 to 2.71938, saving model to ..\results\modelos\cnn_simple_best.h5
#
# Epoch 3: val_loss improved from 9.18921 to 2.71938, saving model to ..\results\modelos\cnn_simple_best.h5
# 131/131 [==============================] - 48s 365ms/step - loss: 0.3972 - accuracy: 0.8826 - precision: 0.9624 - recall: 0.8761 - auc: 0.9448 - val_loss: 2.7194 - val_accuracy: 0.7430 - val_precision: 0.7430 - val_recall: 1.0000 - val_auc: 0.5491 - lr: 0.0010
# Epoch 4/20
# 131/131 [==============================] - 48s 365ms/step - loss: 0.3972 - accuracy: 0.8826 - precision: 0.9624 - recall: 0.8761 - auc: 0.9448 - val_loss: 2.7194 - val_accuracy: 0.7430 - val_precision: 0.7430 - val_recall: 1.0000 - val_auc: 0.5491 - lr: 0.0010
# Epoch 4/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2967 - accuracy: 0.8972 - precision: 0.9684 - recall: 0.8906 - auc: 0.9584
# Epoch 4: val_loss did not improve from 2.71938
# 131/131 [==============================] - 48s 364ms/step - loss: 0.2967 - accuracy: 0.8972 - precision: 0.9684 - recall: 0.8906 - auc: 0.9584 - val_loss: 3.3271 - val_accuracy: 0.7450 - val_precision: 0.7445 - val_recall: 1.0000 - val_auc: 0.5448 - lr: 0.0010
# Epoch 5/20
#
# Epoch 4: val_loss did not improve from 2.71938
# 131/131 [==============================] - 48s 364ms/step - loss: 0.2967 - accuracy: 0.8972 - precision: 0.9684 - recall: 0.8906 - auc: 0.9584 - val_loss: 3.3271 - val_accuracy: 0.7450 - val_precision: 0.7445 - val_recall: 1.0000 - val_auc: 0.5448 - lr: 0.0010
# Epoch 5/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2783 - accuracy: 0.9058 - precision: 0.9724 - recall: 0.8987 - auc: 0.9634
# Epoch 5: val_loss improved from 2.71938 to 1.39389, saving model to ..\results\modelos\cnn_simple_best.h5
#
# Epoch 5: val_loss improved from 2.71938 to 1.39389, saving model to ..\results\modelos\cnn_simple_best.h5
# 131/131 [==============================] - 44s 334ms/step - loss: 0.2783 - accuracy: 0.9058 - precision: 0.9724 - recall: 0.8987 - auc: 0.9634 - val_loss: 1.3939 - val_accuracy: 0.3768 - val_precision: 1.0000 - val_recall: 0.1613 - val_auc: 0.9167 - lr: 0.0010
# Epoch 6/20
# 131/131 [==============================] - 44s 334ms/step - loss: 0.2783 - accuracy: 0.9058 - precision: 0.9724 - recall: 0.8987 - auc: 0.9634 - val_loss: 1.3939 - val_accuracy: 0.3768 - val_precision: 1.0000 - val_recall: 0.1613 - val_auc: 0.9167 - lr: 0.0010
# Epoch 6/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9188 - precision: 0.9736 - recall: 0.9155 - auc: 0.9729
# Epoch 6: val_loss did not improve from 1.39389
# 131/131 [==============================] - 43s 329ms/step - loss: 0.2227 - accuracy: 0.9188 - precision: 0.9736 - recall: 0.9155 - auc: 0.9729 - val_loss: 1.6652 - val_accuracy: 0.3202 - val_precision: 1.0000 - val_recall: 0.0852 - val_auc: 0.9185 - lr: 0.0010
# Epoch 7/20
#
# Epoch 6: val_loss did not improve from 1.39389
# 131/131 [==============================] - 43s 329ms/step - loss: 0.2227 - accuracy: 0.9188 - precision: 0.9736 - recall: 0.9155 - auc: 0.9729 - val_loss: 1.6652 - val_accuracy: 0.3202 - val_precision: 1.0000 - val_recall: 0.0852 - val_auc: 0.9185 - lr: 0.0010
# Epoch 7/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9202 - precision: 0.9802 - recall: 0.9110 - auc: 0.9756
# Epoch 7: val_loss improved from 1.39389 to 0.18018, saving model to ..\results\modelos\cnn_simple_best.h5
#
# Epoch 7: val_loss improved from 1.39389 to 0.18018, saving model to ..\results\modelos\cnn_simple_best.h5
# 131/131 [==============================] - 43s 331ms/step - loss: 0.2106 - accuracy: 0.9202 - precision: 0.9802 - recall: 0.9110 - auc: 0.9756 - val_loss: 0.1802 - val_accuracy: 0.9195 - val_precision: 0.9178 - val_recall: 0.9794 - val_auc: 0.9823 - lr: 0.0010
# 131/131 [==============================] - 43s 331ms/step - loss: 0.2106 - accuracy: 0.9202 - precision: 0.9802 - recall: 0.9110 - auc: 0.9756 - val_loss: 0.1802 - val_accuracy: 0.9195 - val_precision: 0.9178 - val_recall: 0.9794 - val_auc: 0.9823 - lr: 0.0010
# Epoch 8/20
# Epoch 8/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1888 - accuracy: 0.9267 - precision: 0.9788 - recall: 0.9213 - auc: 0.9787
# Epoch 8: val_loss did not improve from 0.18018
# 131/131 [==============================] - 43s 331ms/step - loss: 0.1888 - accuracy: 0.9267 - precision: 0.9788 - recall: 0.9213 - auc: 0.9787 - val_loss: 0.2860 - val_accuracy: 0.8907 - val_precision: 0.9688 - val_recall: 0.8813 - val_auc: 0.9606 - lr: 0.0010
#
# Epoch 8: val_loss did not improve from 0.18018
# 131/131 [==============================] - 43s 331ms/step - loss: 0.1888 - accuracy: 0.9267 - precision: 0.9788 - recall: 0.9213 - auc: 0.9787 - val_loss: 0.2860 - val_accuracy: 0.8907 - val_precision: 0.9688 - val_recall: 0.8813 - val_auc: 0.9606 - lr: 0.0010
# Epoch 9/20
# Epoch 9/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.9274 - precision: 0.9801 - recall: 0.9210 - auc: 0.9804
# Epoch 9: val_loss did not improve from 0.18018
# 131/131 [==============================] - 44s 333ms/step - loss: 0.1755 - accuracy: 0.9274 - precision: 0.9801 - recall: 0.9210 - auc: 0.9804 - val_loss: 0.3040 - val_accuracy: 0.8859 - val_precision: 0.9925 - val_recall: 0.8529 - val_auc: 0.9785 - lr: 0.0010
# Epoch 10/20
#
# Epoch 9: val_loss did not improve from 0.18018
# 131/131 [==============================] - 44s 333ms/step - loss: 0.1755 - accuracy: 0.9274 - precision: 0.9801 - recall: 0.9210 - auc: 0.9804 - val_loss: 0.3040 - val_accuracy: 0.8859 - val_precision: 0.9925 - val_recall: 0.8529 - val_auc: 0.9785 - lr: 0.0010
# Epoch 10/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1741 - accuracy: 0.9339 - precision: 0.9819 - recall: 0.9281 - auc: 0.9812
# Epoch 10: val_loss did not improve from 0.18018
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 [==============================] - 43s 331ms/step - loss: 0.1741 - accuracy: 0.9339 - precision: 0.9819 - recall: 0.9281 - auc: 0.9812 - val_loss: 2.1769 - val_accuracy: 0.7517 - val_precision: 0.7495 - val_recall: 1.0000 - val_auc: 0.6505 - lr: 0.0010
# Epoch 11/20
#
# Epoch 10: val_loss did not improve from 0.18018
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 [==============================] - 43s 331ms/step - loss: 0.1741 - accuracy: 0.9339 - precision: 0.9819 - recall: 0.9281 - auc: 0.9812 - val_loss: 2.1769 - val_accuracy: 0.7517 - val_precision: 0.7495 - val_recall: 1.0000 - val_auc: 0.6505 - lr: 0.0010
# Epoch 11/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.9367 - precision: 0.9833 - recall: 0.9306 - auc: 0.9842
# Epoch 11: val_loss did not improve from 0.18018
# 131/131 [==============================] - 44s 334ms/step - loss: 0.1529 - accuracy: 0.9367 - precision: 0.9833 - recall: 0.9306 - auc: 0.9842 - val_loss: 1.2458 - val_accuracy: 0.4027 - val_precision: 1.0000 - val_recall: 0.1961 - val_auc: 0.9789 - lr: 5.0000e-04
#
# Epoch 11: val_loss did not improve from 0.18018
# 131/131 [==============================] - 44s 334ms/step - loss: 0.1529 - accuracy: 0.9367 - precision: 0.9833 - recall: 0.9306 - auc: 0.9842 - val_loss: 1.2458 - val_accuracy: 0.4027 - val_precision: 1.0000 - val_recall: 0.1961 - val_auc: 0.9789 - lr: 5.0000e-04
# Epoch 12/20
# Epoch 12/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9502 - precision: 0.9872 - recall: 0.9452 - auc: 0.9893Restoring model weights from the end of the best epoch: 7.
#
# Epoch 12: val_loss did not improve from 0.18018
# Restoring model weights from the end of the best epoch: 7.
#
# Epoch 12: val_loss did not improve from 0.18018
# 131/131 [==============================] - 44s 333ms/step - loss: 0.1275 - accuracy: 0.9502 - precision: 0.9872 - recall: 0.9452 - auc: 0.9893 - val_loss: 0.1996 - val_accuracy: 0.9108 - val_precision: 0.9031 - val_recall: 0.9858 - val_auc: 0.9802 - lr: 5.0000e-04
# Epoch 12: early stopping
#
# ✅ Treinamento da CNN Simples concluído!
# 131/131 [==============================] - 44s 333ms/step - loss: 0.1275 - accuracy: 0.9502 - precision: 0.9872 - recall: 0.9452 - auc: 0.9893 - val_loss: 0.1996 - val_accuracy: 0.9108 - val_precision: 0.9031 - val_recall: 0.9858 - val_auc: 0.9802 - lr: 5.0000e-04
# Epoch 12: early stopping
#
# ✅ Treinamento da CNN Simples concluído!

# %%
# Plotar histórico de treinamento
print("\n📈 Visualizando histórico de treinamento...\n")
plot_training_history(history_cnn, save_path=GRAFICOS_DIR / 'cnn_simple_history.png')
# Out:
# 📈 Visualizando histórico de treinamento...
#
# ✅ Figura salva em: ..\results\graficos\cnn_simple_history.png
# ✅ Figura salva em: ..\results\graficos\cnn_simple_history.png
# 📈 Visualizando histórico de treinamento...
#
# ✅ Figura salva em: ..\results\graficos\cnn_simple_history.png
# ✅ Figura salva em: ..\results\graficos\cnn_simple_history.png

# %%
# Avaliar no conjunto de teste
print("\n📊 Avaliando CNN Simples no conjunto de teste...\n")
results_cnn = evaluate_model(model_cnn, test_generator)
# Out:
# 📊 Avaliando CNN Simples no conjunto de teste...
#
# 🔍 Avaliando modelo no conjunto de teste...
#
# 20/20 [==============================] - 2s 112ms/step
#
# 📊 Métricas Gerais:
# ==================================================
# Accuracy:  0.7917 (79.17%)
# F1-Score:  0.8562
# AUC-ROC:   0.9538
# ==================================================
#
# 📋 Relatório Detalhado por Classe:
#
#               precision    recall  f1-score   support
#
#       NORMAL     0.9727    0.4573    0.6221       234
#    PNEUMONIA     0.7529    0.9923    0.8562       390
#
#     accuracy                         0.7917       624
#    macro avg     0.8628    0.7248    0.7391       624
# weighted avg     0.8353    0.7917    0.7684       624

# %%
# Plotar matriz de confusão
plot_confusion_matrix(
    results_cnn['y_true'], 
    results_cnn['predictions'],
    save_path=GRAFICOS_DIR / 'cnn_simple_confusion_matrix.png'
)
# Out:
# ✅ Figura salva em: ..\results\graficos\cnn_simple_confusion_matrix.png
# 📊 Análise da Matriz de Confusão:
# ==================================================
# Verdadeiros Negativos (TN):  107  - Correto: NORMAL como NORMAL
# Falsos Positivos (FP):       127  - Erro: NORMAL como PNEUMONIA
# Falsos Negativos (FN):         3  - Erro: PNEUMONIA como NORMAL ⚠️
# Verdadeiros Positivos (TP):  387  - Correto: PNEUMONIA como PNEUMONIA
# ==================================================
#
# ⚠️ IMPORTANTE: Falsos Negativos são críticos em medicina!
#    Não detectar uma pneumonia real pode ter consequências graves.

# %%
# Plotar curva ROC
plot_roc_curve(
    results_cnn['y_true'], 
    results_cnn['predictions_prob'],
    save_path=GRAFICOS_DIR / 'cnn_simple_roc_curve.png'
)
# Out:
# ✅ Figura salva em: ..\results\graficos\cnn_simple_roc_curve.png
# 📈 Interpretação da Curva ROC:
# ==================================================
# AUC = 0.9538
#    Excelente capacidade de discriminação! 🌟
# ==================================================

# %% [markdown]
# ## 2️⃣ Modelo 2: VGG16 Transfer Learning
#
# Agora vamos usar Transfer Learning com VGG16, um modelo já treinado no ImageNet. Isso geralmente dá melhores resultados!

# %%
print("\n" + "="*70)
print("🔧 MODELO 2: VGG16 TRANSFER LEARNING")
print("="*70)

# Criar modelo
model_vgg16 = create_vgg16_transfer(input_shape=(*IMG_SIZE, 3), trainable_layers=4)

# Ver arquitetura
print_model_summary(model_vgg16, "VGG16 Transfer Learning")
# Out:
# ======================================================================
# 🔧 MODELO 2: VGG16 TRANSFER LEARNING
# ======================================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
#
# ============================================================
# 📊 Resumo do VGG16 Transfer Learning
# ============================================================
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 14,879,041
# Trainable params: 7,243,777
# Non-trainable params: 7,635,264
# _________________________________________________________________
#
# ============================================================
# Total de parâmetros: 14,879,041
# Parâmetros treináveis: 7,243,777
# Parâmetros não-treináveis: 7,635,264
# ============================================================

# %%
# Treinar modelo
print("\n🚀 Iniciando treinamento do VGG16...\n")
print("💡 Este modelo pode demorar mais, mas geralmente tem melhor desempenho!\n")

history_vgg16 = model_vgg16.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    class_weight=class_weights,
    callbacks=get_callbacks('vgg16_transfer'),
    verbose=1
)

print("\n✅ Treinamento do VGG16 concluído!")
# Out:
# 🚀 Iniciando treinamento do VGG16...
#
# 💡 Este modelo pode demorar mais, mas geralmente tem melhor desempenho!
#
# Epoch 1/20
# Epoch 1/20
# 131/131 [==============================] - ETA: 0s - loss: 0.7916 - accuracy: 0.5080 - precision: 0.7407 - recall: 0.5197 - auc: 0.4980
# Epoch 1: val_loss improved from inf to 0.75180, saving model to ..\results\modelos\vgg16_transfer_best.h5
#
# Epoch 1: val_loss improved from inf to 0.75180, saving model to ..\results\modelos\vgg16_transfer_best.h5
# 131/131 [==============================] - 50s 362ms/step - loss: 0.7916 - accuracy: 0.5080 - precision: 0.7407 - recall: 0.5197 - auc: 0.4980 - val_loss: 0.7518 - val_accuracy: 0.2752 - val_precision: 1.0000 - val_recall: 0.0245 - val_auc: 0.5799 - lr: 1.0000e-04
# 131/131 [==============================] - 50s 362ms/step - loss: 0.7916 - accuracy: 0.5080 - precision: 0.7407 - recall: 0.5197 - auc: 0.4980 - val_loss: 0.7518 - val_accuracy: 0.2752 - val_precision: 1.0000 - val_recall: 0.0245 - val_auc: 0.5799 - lr: 1.0000e-04
# Epoch 2/20
# Epoch 2/20
# 131/131 [==============================] - ETA: 0s - loss: 0.7928 - accuracy: 0.4941 - precision: 0.7442 - recall: 0.4861 - auc: 0.4982
# Epoch 2: val_loss improved from 0.75180 to 0.71887, saving model to ..\results\modelos\vgg16_transfer_best.h5
#
# Epoch 2: val_loss improved from 0.75180 to 0.71887, saving model to ..\results\modelos\vgg16_transfer_best.h5
# 131/131 [==============================] - 51s 394ms/step - loss: 0.7928 - accuracy: 0.4941 - precision: 0.7442 - recall: 0.4861 - auc: 0.4982 - val_loss: 0.7189 - val_accuracy: 0.2780 - val_precision: 1.0000 - val_recall: 0.0284 - val_auc: 0.6744 - lr: 1.0000e-04
# 131/131 [==============================] - 51s 394ms/step - loss: 0.7928 - accuracy: 0.4941 - precision: 0.7442 - recall: 0.4861 - auc: 0.4982 - val_loss: 0.7189 - val_accuracy: 0.2780 - val_precision: 1.0000 - val_recall: 0.0284 - val_auc: 0.6744 - lr: 1.0000e-04
# Epoch 3/20
# Epoch 3/20
# 131/131 [==============================] - ETA: 0s - loss: 5.0412 - accuracy: 0.4980 - precision: 0.7576 - recall: 0.4768 - auc: 0.5138
# Epoch 3: val_loss improved from 0.71887 to 0.67637, saving model to ..\results\modelos\vgg16_transfer_best.h5
#
# Epoch 3: val_loss improved from 0.71887 to 0.67637, saving model to ..\results\modelos\vgg16_transfer_best.h5
# 131/131 [==============================] - 47s 362ms/step - loss: 5.0412 - accuracy: 0.4980 - precision: 0.7576 - recall: 0.4768 - auc: 0.5138 - val_loss: 0.6764 - val_accuracy: 0.7143 - val_precision: 0.7601 - val_recall: 0.8994 - val_auc: 0.6183 - lr: 1.0000e-04
# Epoch 4/20
# 131/131 [==============================] - 47s 362ms/step - loss: 5.0412 - accuracy: 0.4980 - precision: 0.7576 - recall: 0.4768 - auc: 0.5138 - val_loss: 0.6764 - val_accuracy: 0.7143 - val_precision: 0.7601 - val_recall: 0.8994 - val_auc: 0.6183 - lr: 1.0000e-04
# Epoch 4/20
# 131/131 [==============================] - ETA: 0s - loss: 1.6993 - accuracy: 0.5222 - precision: 0.7341 - recall: 0.5594 - auc: 0.4803
# Epoch 4: val_loss improved from 0.67637 to 0.66045, saving model to ..\results\modelos\vgg16_transfer_best.h5
#
# Epoch 4: val_loss improved from 0.67637 to 0.66045, saving model to ..\results\modelos\vgg16_transfer_best.h5
# 131/131 [==============================] - 43s 326ms/step - loss: 1.6993 - accuracy: 0.5222 - precision: 0.7341 - recall: 0.5594 - auc: 0.4803 - val_loss: 0.6604 - val_accuracy: 0.7411 - val_precision: 0.7426 - val_recall: 0.9974 - val_auc: 0.5638 - lr: 1.0000e-04
# Epoch 5/20
# 131/131 [==============================] - 43s 326ms/step - loss: 1.6993 - accuracy: 0.5222 - precision: 0.7341 - recall: 0.5594 - auc: 0.4803 - val_loss: 0.6604 - val_accuracy: 0.7411 - val_precision: 0.7426 - val_recall: 0.9974 - val_auc: 0.5638 - lr: 1.0000e-04
# Epoch 5/20
# 131/131 [==============================] - ETA: 0s - loss: 4.9213 - accuracy: 0.5140 - precision: 0.7495 - recall: 0.5194 - auc: 0.5071
# Epoch 5: val_loss did not improve from 0.66045
# 131/131 [==============================] - 43s 328ms/step - loss: 4.9213 - accuracy: 0.5140 - precision: 0.7495 - recall: 0.5194 - auc: 0.5071 - val_loss: 0.6885 - val_accuracy: 0.5580 - val_precision: 0.7445 - val_recall: 0.6168 - val_auc: 0.4975 - lr: 1.0000e-04
# Epoch 6/20
#
# Epoch 5: val_loss did not improve from 0.66045
# 131/131 [==============================] - 43s 328ms/step - loss: 4.9213 - accuracy: 0.5140 - precision: 0.7495 - recall: 0.5194 - auc: 0.5071 - val_loss: 0.6885 - val_accuracy: 0.5580 - val_precision: 0.7445 - val_recall: 0.6168 - val_auc: 0.4975 - lr: 1.0000e-04
# Epoch 6/20
# 131/131 [==============================] - ETA: 0s - loss: 1.6725 - accuracy: 0.5306 - precision: 0.7460 - recall: 0.5581 - auc: 0.4954
# Epoch 6: val_loss did not improve from 0.66045
# 131/131 [==============================] - 43s 329ms/step - loss: 1.6725 - accuracy: 0.5306 - precision: 0.7460 - recall: 0.5581 - auc: 0.4954 - val_loss: 0.6842 - val_accuracy: 0.6663 - val_precision: 0.7545 - val_recall: 0.8168 - val_auc: 0.5522 - lr: 1.0000e-04
#
# Epoch 6: val_loss did not improve from 0.66045
# 131/131 [==============================] - 43s 329ms/step - loss: 1.6725 - accuracy: 0.5306 - precision: 0.7460 - recall: 0.5581 - auc: 0.4954 - val_loss: 0.6842 - val_accuracy: 0.6663 - val_precision: 0.7545 - val_recall: 0.8168 - val_auc: 0.5522 - lr: 1.0000e-04
# Epoch 7/20
# Epoch 7/20
# 131/131 [==============================] - ETA: 0s - loss: 1.4300 - accuracy: 0.4917 - precision: 0.7377 - recall: 0.4900 - auc: 0.4919
# Epoch 7: val_loss did not improve from 0.66045
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 131/131 [==============================] - 43s 328ms/step - loss: 1.4300 - accuracy: 0.4917 - precision: 0.7377 - recall: 0.4900 - auc: 0.4919 - val_loss: 0.6731 - val_accuracy: 0.7335 - val_precision: 0.7468 - val_recall: 0.9703 - val_auc: 0.6208 - lr: 1.0000e-04
# Epoch 8/20
#
# Epoch 7: val_loss did not improve from 0.66045
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 131/131 [==============================] - 43s 328ms/step - loss: 1.4300 - accuracy: 0.4917 - precision: 0.7377 - recall: 0.4900 - auc: 0.4919 - val_loss: 0.6731 - val_accuracy: 0.7335 - val_precision: 0.7468 - val_recall: 0.9703 - val_auc: 0.6208 - lr: 1.0000e-04
# Epoch 8/20
# 131/131 [==============================] - ETA: 0s - loss: 3.0433 - accuracy: 0.5622 - precision: 0.7419 - recall: 0.6297 - auc: 0.4928
# Epoch 8: val_loss did not improve from 0.66045
# 131/131 [==============================] - 43s 326ms/step - loss: 3.0433 - accuracy: 0.5622 - precision: 0.7419 - recall: 0.6297 - auc: 0.4928 - val_loss: 0.6999 - val_accuracy: 0.2905 - val_precision: 1.0000 - val_recall: 0.0452 - val_auc: 0.7296 - lr: 5.0000e-05
# Epoch 9/20
#
# Epoch 8: val_loss did not improve from 0.66045
# 131/131 [==============================] - 43s 326ms/step - loss: 3.0433 - accuracy: 0.5622 - precision: 0.7419 - recall: 0.6297 - auc: 0.4928 - val_loss: 0.6999 - val_accuracy: 0.2905 - val_precision: 1.0000 - val_recall: 0.0452 - val_auc: 0.7296 - lr: 5.0000e-05
# Epoch 9/20
# 131/131 [==============================] - ETA: 0s - loss: 1.8674 - accuracy: 0.4798 - precision: 0.7540 - recall: 0.4448 - auc: 0.5172Restoring model weights from the end of the best epoch: 4.
#
# Epoch 9: val_loss did not improve from 0.66045
# Restoring model weights from the end of the best epoch: 4.
#
# Epoch 9: val_loss did not improve from 0.66045
# 131/131 [==============================] - 43s 328ms/step - loss: 1.8674 - accuracy: 0.4798 - precision: 0.7540 - recall: 0.4448 - auc: 0.5172 - val_loss: 0.6930 - val_accuracy: 0.4113 - val_precision: 0.7622 - val_recall: 0.3019 - val_auc: 0.5189 - lr: 5.0000e-05
# Epoch 9: early stopping
#
# ✅ Treinamento do VGG16 concluído!
# 131/131 [==============================] - 43s 328ms/step - loss: 1.8674 - accuracy: 0.4798 - precision: 0.7540 - recall: 0.4448 - auc: 0.5172 - val_loss: 0.6930 - val_accuracy: 0.4113 - val_precision: 0.7622 - val_recall: 0.3019 - val_auc: 0.5189 - lr: 5.0000e-05
# Epoch 9: early stopping
#
# ✅ Treinamento do VGG16 concluído!

# %%
# Plotar histórico
print("\n📈 Visualizando histórico de treinamento...\n")
plot_training_history(history_vgg16, save_path=GRAFICOS_DIR / 'vgg16_history.png')
# Out:
# 📈 Visualizando histórico de treinamento...
#
# ✅ Figura salva em: ..\results\graficos\vgg16_history.png
# ✅ Figura salva em: ..\results\graficos\vgg16_history.png

# %%
# Avaliar no conjunto de teste
print("\n📊 Avaliando VGG16 no conjunto de teste...\n")
results_vgg16 = evaluate_model(model_vgg16, test_generator)
# Out:
# 📊 Avaliando VGG16 no conjunto de teste...
#
# 🔍 Avaliando modelo no conjunto de teste...
#
# 20/20 [==============================] - 4s 168ms/step
#
# 📊 Métricas Gerais:
# ==================================================
# Accuracy:  0.6250 (62.50%)
# F1-Score:  0.7692
# AUC-ROC:   0.6141
# ==================================================
#
# 📋 Relatório Detalhado por Classe:
#
#               precision    recall  f1-score   support
#
#       NORMAL     0.0000    0.0000    0.0000       234
#    PNEUMONIA     0.6250    1.0000    0.7692       390
#
#     accuracy                         0.6250       624
#    macro avg     0.3125    0.5000    0.3846       624
# weighted avg     0.3906    0.6250    0.4808       624
#
# 20/20 [==============================] - 4s 168ms/step
#
# 📊 Métricas Gerais:
# ==================================================
# Accuracy:  0.6250 (62.50%)
# F1-Score:  0.7692
# AUC-ROC:   0.6141
# ==================================================
#
# 📋 Relatório Detalhado por Classe:
#
#               precision    recall  f1-score   support
#
#       NORMAL     0.0000    0.0000    0.0000       234
#    PNEUMONIA     0.6250    1.0000    0.7692       390
#
#     accuracy                         0.6250       624
#    macro avg     0.3125    0.5000    0.3846       624
# weighted avg     0.3906    0.6250    0.4808       624

# %%
# Plotar matriz de confusão
plot_confusion_matrix(
    results_vgg16['y_true'], 
    results_vgg16['predictions'],
    save_path=GRAFICOS_DIR / 'vgg16_confusion_matrix.png'
)
# Out:
# ✅ Figura salva em: ..\results\graficos\vgg16_confusion_matrix.png
# 📊 Análise da Matriz de Confusão:
# ==================================================
# Verdadeiros Negativos (TN):    0  - Correto: NORMAL como NORMAL
# Falsos Positivos (FP):       234  - Erro: NORMAL como PNEUMONIA
# Falsos Negativos (FN):         0  - Erro: PNEUMONIA como NORMAL ⚠️
# Verdadeiros Positivos (TP):  390  - Correto: PNEUMONIA como PNEUMONIA
# ==================================================
#
# ⚠️ IMPORTANTE: Falsos Negativos são críticos em medicina!
#    Não detectar uma pneumonia real pode ter consequências graves.

# %%
# Plotar curva ROC
plot_roc_curve(
    results_vgg16['y_true'], 
    results_vgg16['predictions_prob'],
    save_path=GRAFICOS_DIR / 'vgg16_roc_curve.png'
)
# Out:
# ✅ Figura salva em: ..\results\graficos\vgg16_roc_curve.png
# 📈 Interpretação da Curva ROC:
# ==================================================
# AUC = 0.6141
#    Capacidade limitada de discriminação. ⚠️
# ==================================================

# %% [markdown]
# ## 3️⃣ Modelo 3: ResNet50 Transfer Learning
#
# Por último, vamos treinar com ResNet50, uma arquitetura mais moderna que geralmente supera a VGG16!

# %%
print("\n" + "="*70)
print("🔧 MODELO 3: RESNET50 TRANSFER LEARNING")
print("="*70)

# Criar modelo
model_resnet50 = create_resnet50_transfer(input_shape=(*IMG_SIZE, 3), trainable_layers=10)

# Ver arquitetura
print_model_summary(model_resnet50, "ResNet50 Transfer Learning")
# Out:
# ======================================================================
# 🔧 MODELO 3: RESNET50 TRANSFER LEARNING
# ======================================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 4s 0us/step
# 94765736/94765736 [==============================] - 4s 0us/step
#
# ============================================================
# 📊 Resumo do ResNet50 Transfer Learning
# ============================================================
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 512)               1049088
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#
# ============================================================
# 📊 Resumo do ResNet50 Transfer Learning
# ============================================================
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 512)               1049088
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 24,771,457
# Trainable params: 5,647,873
# Non-trainable params: 19,123,584
# _________________________________________________________________
#  dense_8 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 24,771,457
# Trainable params: 5,647,873
# Non-trainable params: 19,123,584
# _________________________________________________________________
#
# ============================================================
# Total de parâmetros: 24,771,457
# Parâmetros treináveis: 5,647,873
# Parâmetros não-treináveis: 19,123,584
# ============================================================
#
#
# ============================================================
# Total de parâmetros: 24,771,457
# Parâmetros treináveis: 5,647,873
# Parâmetros não-treináveis: 19,123,584
# ============================================================

# %%
# Treinar modelo
print("\n🚀 Iniciando treinamento do ResNet50...\n")
print("💡 ResNet50 usa conexões residuais - uma arquitetura mais moderna!\n")

history_resnet50 = model_resnet50.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    class_weight=class_weights,
    callbacks=get_callbacks('resnet50_transfer'),
    verbose=1
)

print("\n✅ Treinamento do ResNet50 concluído!")
# Out:
# 🚀 Iniciando treinamento do ResNet50...
#
# 💡 ResNet50 usa conexões residuais - uma arquitetura mais moderna!
#
# Epoch 1/20
# Epoch 1/20
# 131/131 [==============================] - ETA: 0s - loss: 0.4379 - accuracy: 0.7956 - precision: 0.9584 - recall: 0.7577 - auc: 0.9090
# Epoch 1: val_loss improved from inf to 0.74153, saving model to ..\results\modelos\resnet50_transfer_best.h5
#
# Epoch 1: val_loss improved from inf to 0.74153, saving model to ..\results\modelos\resnet50_transfer_best.h5
# 131/131 [==============================] - 47s 338ms/step - loss: 0.4379 - accuracy: 0.7956 - precision: 0.9584 - recall: 0.7577 - auc: 0.9090 - val_loss: 0.7415 - val_accuracy: 0.2570 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9108 - lr: 1.0000e-04
# 131/131 [==============================] - 47s 338ms/step - loss: 0.4379 - accuracy: 0.7956 - precision: 0.9584 - recall: 0.7577 - auc: 0.9090 - val_loss: 0.7415 - val_accuracy: 0.2570 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9108 - lr: 1.0000e-04
# Epoch 2/20
# Epoch 2/20
# 131/131 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.8533 - precision: 0.9726 - recall: 0.8258 - auc: 0.9421
# Epoch 2: val_loss improved from 0.74153 to 0.51290, saving model to ..\results\modelos\resnet50_transfer_best.h5
#
# Epoch 2: val_loss improved from 0.74153 to 0.51290, saving model to ..\results\modelos\resnet50_transfer_best.h5
# 131/131 [==============================] - 44s 337ms/step - loss: 0.3473 - accuracy: 0.8533 - precision: 0.9726 - recall: 0.8258 - auc: 0.9421 - val_loss: 0.5129 - val_accuracy: 0.7430 - val_precision: 0.7430 - val_recall: 1.0000 - val_auc: 0.9254 - lr: 1.0000e-04
# 131/131 [==============================] - 44s 337ms/step - loss: 0.3473 - accuracy: 0.8533 - precision: 0.9726 - recall: 0.8258 - auc: 0.9421 - val_loss: 0.5129 - val_accuracy: 0.7430 - val_precision: 0.7430 - val_recall: 1.0000 - val_auc: 0.9254 - lr: 1.0000e-04
# Epoch 3/20
# Epoch 3/20
# 131/131 [==============================] - ETA: 0s - loss: 0.3025 - accuracy: 0.8740 - precision: 0.9732 - recall: 0.8539 - auc: 0.9523
# Epoch 3: val_loss did not improve from 0.51290
# 131/131 [==============================] - 44s 334ms/step - loss: 0.3025 - accuracy: 0.8740 - precision: 0.9732 - recall: 0.8539 - auc: 0.9523 - val_loss: 0.6528 - val_accuracy: 0.6194 - val_precision: 1.0000 - val_recall: 0.4877 - val_auc: 0.9740 - lr: 1.0000e-04
#
# Epoch 3: val_loss did not improve from 0.51290
# 131/131 [==============================] - 44s 334ms/step - loss: 0.3025 - accuracy: 0.8740 - precision: 0.9732 - recall: 0.8539 - auc: 0.9523 - val_loss: 0.6528 - val_accuracy: 0.6194 - val_precision: 1.0000 - val_recall: 0.4877 - val_auc: 0.9740 - lr: 1.0000e-04
# Epoch 4/20
# Epoch 4/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8847 - precision: 0.9709 - recall: 0.8710 - auc: 0.9567
# Epoch 4: val_loss did not improve from 0.51290
# 131/131 [==============================] - 46s 349ms/step - loss: 0.2832 - accuracy: 0.8847 - precision: 0.9709 - recall: 0.8710 - auc: 0.9567 - val_loss: 0.6074 - val_accuracy: 0.7517 - val_precision: 1.0000 - val_recall: 0.6658 - val_auc: 0.9744 - lr: 1.0000e-04
#
# Epoch 4: val_loss did not improve from 0.51290
# 131/131 [==============================] - 46s 349ms/step - loss: 0.2832 - accuracy: 0.8847 - precision: 0.9709 - recall: 0.8710 - auc: 0.9567 - val_loss: 0.6074 - val_accuracy: 0.7517 - val_precision: 1.0000 - val_recall: 0.6658 - val_auc: 0.9744 - lr: 1.0000e-04
# Epoch 5/20
# Epoch 5/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2917 - accuracy: 0.8850 - precision: 0.9679 - recall: 0.8742 - auc: 0.9553
# Epoch 5: val_loss did not improve from 0.51290
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 131/131 [==============================] - 43s 330ms/step - loss: 0.2917 - accuracy: 0.8850 - precision: 0.9679 - recall: 0.8742 - auc: 0.9553 - val_loss: 0.5219 - val_accuracy: 0.7795 - val_precision: 0.7739 - val_recall: 0.9935 - val_auc: 0.9613 - lr: 1.0000e-04
#
# Epoch 5: val_loss did not improve from 0.51290
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 131/131 [==============================] - 43s 330ms/step - loss: 0.2917 - accuracy: 0.8850 - precision: 0.9679 - recall: 0.8742 - auc: 0.9553 - val_loss: 0.5219 - val_accuracy: 0.7795 - val_precision: 0.7739 - val_recall: 0.9935 - val_auc: 0.9613 - lr: 1.0000e-04
# Epoch 6/20
# Epoch 6/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2509 - accuracy: 0.8984 - precision: 0.9741 - recall: 0.8868 - auc: 0.9654
# Epoch 6: val_loss improved from 0.51290 to 0.20620, saving model to ..\results\modelos\resnet50_transfer_best.h5
#
# Epoch 6: val_loss improved from 0.51290 to 0.20620, saving model to ..\results\modelos\resnet50_transfer_best.h5
# 131/131 [==============================] - 44s 336ms/step - loss: 0.2509 - accuracy: 0.8984 - precision: 0.9741 - recall: 0.8868 - auc: 0.9654 - val_loss: 0.2062 - val_accuracy: 0.9252 - val_precision: 0.9451 - val_recall: 0.9548 - val_auc: 0.9701 - lr: 5.0000e-05
# 131/131 [==============================] - 44s 336ms/step - loss: 0.2509 - accuracy: 0.8984 - precision: 0.9741 - recall: 0.8868 - auc: 0.9654 - val_loss: 0.2062 - val_accuracy: 0.9252 - val_precision: 0.9451 - val_recall: 0.9548 - val_auc: 0.9701 - lr: 5.0000e-05
# Epoch 7/20
# Epoch 7/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2435 - accuracy: 0.9008 - precision: 0.9716 - recall: 0.8926 - auc: 0.9668
# Epoch 7: val_loss did not improve from 0.20620
# 131/131 [==============================] - 44s 333ms/step - loss: 0.2435 - accuracy: 0.9008 - precision: 0.9716 - recall: 0.8926 - auc: 0.9668 - val_loss: 0.3845 - val_accuracy: 0.8274 - val_precision: 0.8135 - val_recall: 0.9961 - val_auc: 0.9777 - lr: 5.0000e-05
#
# Epoch 7: val_loss did not improve from 0.20620
# 131/131 [==============================] - 44s 333ms/step - loss: 0.2435 - accuracy: 0.9008 - precision: 0.9716 - recall: 0.8926 - auc: 0.9668 - val_loss: 0.3845 - val_accuracy: 0.8274 - val_precision: 0.8135 - val_recall: 0.9961 - val_auc: 0.9777 - lr: 5.0000e-05
# Epoch 8/20
# Epoch 8/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9092 - precision: 0.9735 - recall: 0.9023 - auc: 0.9693
# Epoch 8: val_loss did not improve from 0.20620
# 131/131 [==============================] - 43s 329ms/step - loss: 0.2346 - accuracy: 0.9092 - precision: 0.9735 - recall: 0.9023 - auc: 0.9693 - val_loss: 0.6091 - val_accuracy: 0.8159 - val_precision: 0.9949 - val_recall: 0.7561 - val_auc: 0.9692 - lr: 5.0000e-05
# Epoch 9/20
#
# Epoch 8: val_loss did not improve from 0.20620
# 131/131 [==============================] - 43s 329ms/step - loss: 0.2346 - accuracy: 0.9092 - precision: 0.9735 - recall: 0.9023 - auc: 0.9693 - val_loss: 0.6091 - val_accuracy: 0.8159 - val_precision: 0.9949 - val_recall: 0.7561 - val_auc: 0.9692 - lr: 5.0000e-05
# Epoch 9/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2192 - accuracy: 0.9121 - precision: 0.9763 - recall: 0.9035 - auc: 0.9730
# Epoch 9: val_loss did not improve from 0.20620
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 131/131 [==============================] - 44s 337ms/step - loss: 0.2192 - accuracy: 0.9121 - precision: 0.9763 - recall: 0.9035 - auc: 0.9730 - val_loss: 0.2720 - val_accuracy: 0.9108 - val_precision: 0.9858 - val_recall: 0.8929 - val_auc: 0.9831 - lr: 5.0000e-05
# Epoch 10/20
#
# Epoch 9: val_loss did not improve from 0.20620
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 131/131 [==============================] - 44s 337ms/step - loss: 0.2192 - accuracy: 0.9121 - precision: 0.9763 - recall: 0.9035 - auc: 0.9730 - val_loss: 0.2720 - val_accuracy: 0.9108 - val_precision: 0.9858 - val_recall: 0.8929 - val_auc: 0.9831 - lr: 5.0000e-05
# Epoch 10/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9147 - precision: 0.9764 - recall: 0.9071 - auc: 0.9720
# Epoch 10: val_loss improved from 0.20620 to 0.18123, saving model to ..\results\modelos\resnet50_transfer_best.h5
#
# Epoch 10: val_loss improved from 0.20620 to 0.18123, saving model to ..\results\modelos\resnet50_transfer_best.h5
# 131/131 [==============================] - 44s 333ms/step - loss: 0.2208 - accuracy: 0.9147 - precision: 0.9764 - recall: 0.9071 - auc: 0.9720 - val_loss: 0.1812 - val_accuracy: 0.9453 - val_precision: 0.9851 - val_recall: 0.9406 - val_auc: 0.9859 - lr: 2.5000e-05
# Epoch 11/20
# 131/131 [==============================] - 44s 333ms/step - loss: 0.2208 - accuracy: 0.9147 - precision: 0.9764 - recall: 0.9071 - auc: 0.9720 - val_loss: 0.1812 - val_accuracy: 0.9453 - val_precision: 0.9851 - val_recall: 0.9406 - val_auc: 0.9859 - lr: 2.5000e-05
# Epoch 11/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2140 - accuracy: 0.9145 - precision: 0.9780 - recall: 0.9052 - auc: 0.9742
# Epoch 11: val_loss did not improve from 0.18123
# 131/131 [==============================] - 43s 328ms/step - loss: 0.2140 - accuracy: 0.9145 - precision: 0.9780 - recall: 0.9052 - auc: 0.9742 - val_loss: 0.5874 - val_accuracy: 0.8303 - val_precision: 1.0000 - val_recall: 0.7716 - val_auc: 0.9790 - lr: 2.5000e-05
# Epoch 12/20
#
# Epoch 11: val_loss did not improve from 0.18123
# 131/131 [==============================] - 43s 328ms/step - loss: 0.2140 - accuracy: 0.9145 - precision: 0.9780 - recall: 0.9052 - auc: 0.9742 - val_loss: 0.5874 - val_accuracy: 0.8303 - val_precision: 1.0000 - val_recall: 0.7716 - val_auc: 0.9790 - lr: 2.5000e-05
# Epoch 12/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2234 - accuracy: 0.9121 - precision: 0.9753 - recall: 0.9045 - auc: 0.9724
# Epoch 12: val_loss did not improve from 0.18123
# 131/131 [==============================] - 43s 328ms/step - loss: 0.2234 - accuracy: 0.9121 - precision: 0.9753 - recall: 0.9045 - auc: 0.9724 - val_loss: 0.3286 - val_accuracy: 0.8907 - val_precision: 0.9925 - val_recall: 0.8594 - val_auc: 0.9800 - lr: 2.5000e-05
# Epoch 13/20
#
# Epoch 12: val_loss did not improve from 0.18123
# 131/131 [==============================] - 43s 328ms/step - loss: 0.2234 - accuracy: 0.9121 - precision: 0.9753 - recall: 0.9045 - auc: 0.9724 - val_loss: 0.3286 - val_accuracy: 0.8907 - val_precision: 0.9925 - val_recall: 0.8594 - val_auc: 0.9800 - lr: 2.5000e-05
# Epoch 13/20
# 131/131 [==============================] - ETA: 0s - loss: 0.2068 - accuracy: 0.9183 - precision: 0.9782 - recall: 0.9103 - auc: 0.9749
# Epoch 13: val_loss did not improve from 0.18123
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 131/131 [==============================] - 46s 349ms/step - loss: 0.2068 - accuracy: 0.9183 - precision: 0.9782 - recall: 0.9103 - auc: 0.9749 - val_loss: 0.2178 - val_accuracy: 0.9252 - val_precision: 0.9781 - val_recall: 0.9200 - val_auc: 0.9814 - lr: 2.5000e-05
#
# Epoch 13: val_loss did not improve from 0.18123
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 131/131 [==============================] - 46s 349ms/step - loss: 0.2068 - accuracy: 0.9183 - precision: 0.9782 - recall: 0.9103 - auc: 0.9749 - val_loss: 0.2178 - val_accuracy: 0.9252 - val_precision: 0.9781 - val_recall: 0.9200 - val_auc: 0.9814 - lr: 2.5000e-05
# Epoch 14/20
# Epoch 14/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9262 - precision: 0.9817 - recall: 0.9177 - auc: 0.9782
# Epoch 14: val_loss improved from 0.18123 to 0.17368, saving model to ..\results\modelos\resnet50_transfer_best.h5
#
# Epoch 14: val_loss improved from 0.18123 to 0.17368, saving model to ..\results\modelos\resnet50_transfer_best.h5
# 131/131 [==============================] - 47s 358ms/step - loss: 0.1953 - accuracy: 0.9262 - precision: 0.9817 - recall: 0.9177 - auc: 0.9782 - val_loss: 0.1737 - val_accuracy: 0.9377 - val_precision: 0.9449 - val_recall: 0.9729 - val_auc: 0.9793 - lr: 1.2500e-05
# Epoch 15/20
# 131/131 [==============================] - 47s 358ms/step - loss: 0.1953 - accuracy: 0.9262 - precision: 0.9817 - recall: 0.9177 - auc: 0.9782 - val_loss: 0.1737 - val_accuracy: 0.9377 - val_precision: 0.9449 - val_recall: 0.9729 - val_auc: 0.9793 - lr: 1.2500e-05
# Epoch 15/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1965 - accuracy: 0.9245 - precision: 0.9800 - recall: 0.9171 - auc: 0.9777
# Epoch 15: val_loss did not improve from 0.17368
# 131/131 [==============================] - 43s 331ms/step - loss: 0.1965 - accuracy: 0.9245 - precision: 0.9800 - recall: 0.9171 - auc: 0.9777 - val_loss: 0.2428 - val_accuracy: 0.9243 - val_precision: 0.9915 - val_recall: 0.9058 - val_auc: 0.9830 - lr: 1.2500e-05
# Epoch 16/20
#
# Epoch 15: val_loss did not improve from 0.17368
# 131/131 [==============================] - 43s 331ms/step - loss: 0.1965 - accuracy: 0.9245 - precision: 0.9800 - recall: 0.9171 - auc: 0.9777 - val_loss: 0.2428 - val_accuracy: 0.9243 - val_precision: 0.9915 - val_recall: 0.9058 - val_auc: 0.9830 - lr: 1.2500e-05
# Epoch 16/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9262 - precision: 0.9794 - recall: 0.9200 - auc: 0.9763
# Epoch 16: val_loss did not improve from 0.17368
# 131/131 [==============================] - 45s 343ms/step - loss: 0.1998 - accuracy: 0.9262 - precision: 0.9794 - recall: 0.9200 - auc: 0.9763 - val_loss: 0.4740 - val_accuracy: 0.8648 - val_precision: 0.9984 - val_recall: 0.8194 - val_auc: 0.9796 - lr: 1.2500e-05
# Epoch 17/20
#
# Epoch 16: val_loss did not improve from 0.17368
# 131/131 [==============================] - 45s 343ms/step - loss: 0.1998 - accuracy: 0.9262 - precision: 0.9794 - recall: 0.9200 - auc: 0.9763 - val_loss: 0.4740 - val_accuracy: 0.8648 - val_precision: 0.9984 - val_recall: 0.8194 - val_auc: 0.9796 - lr: 1.2500e-05
# Epoch 17/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.9286 - precision: 0.9834 - recall: 0.9194 - auc: 0.9796
# Epoch 17: val_loss did not improve from 0.17368
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 131/131 [==============================] - 43s 331ms/step - loss: 0.1870 - accuracy: 0.9286 - precision: 0.9834 - recall: 0.9194 - auc: 0.9796 - val_loss: 0.2862 - val_accuracy: 0.9195 - val_precision: 0.9929 - val_recall: 0.8981 - val_auc: 0.9803 - lr: 1.2500e-05
# Epoch 18/20
#
# Epoch 17: val_loss did not improve from 0.17368
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 131/131 [==============================] - 43s 331ms/step - loss: 0.1870 - accuracy: 0.9286 - precision: 0.9834 - recall: 0.9194 - auc: 0.9796 - val_loss: 0.2862 - val_accuracy: 0.9195 - val_precision: 0.9929 - val_recall: 0.8981 - val_auc: 0.9803 - lr: 1.2500e-05
# Epoch 18/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 0.9250 - precision: 0.9817 - recall: 0.9161 - auc: 0.9773
# Epoch 18: val_loss did not improve from 0.17368
# 131/131 [==============================] - 43s 330ms/step - loss: 0.1941 - accuracy: 0.9250 - precision: 0.9817 - recall: 0.9161 - auc: 0.9773 - val_loss: 0.1910 - val_accuracy: 0.9262 - val_precision: 0.9195 - val_recall: 0.9871 - val_auc: 0.9848 - lr: 6.2500e-06
# Epoch 19/20
#
# Epoch 18: val_loss did not improve from 0.17368
# 131/131 [==============================] - 43s 330ms/step - loss: 0.1941 - accuracy: 0.9250 - precision: 0.9817 - recall: 0.9161 - auc: 0.9773 - val_loss: 0.1910 - val_accuracy: 0.9262 - val_precision: 0.9195 - val_recall: 0.9871 - val_auc: 0.9848 - lr: 6.2500e-06
# Epoch 19/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.9269 - precision: 0.9804 - recall: 0.9200 - auc: 0.9802
# Epoch 19: val_loss improved from 0.17368 to 0.16134, saving model to ..\results\modelos\resnet50_transfer_best.h5
#
# Epoch 19: val_loss improved from 0.17368 to 0.16134, saving model to ..\results\modelos\resnet50_transfer_best.h5
# 131/131 [==============================] - 44s 337ms/step - loss: 0.1871 - accuracy: 0.9269 - precision: 0.9804 - recall: 0.9200 - auc: 0.9802 - val_loss: 0.1613 - val_accuracy: 0.9396 - val_precision: 0.9599 - val_recall: 0.9587 - val_auc: 0.9833 - lr: 6.2500e-06
# 131/131 [==============================] - 44s 337ms/step - loss: 0.1871 - accuracy: 0.9269 - precision: 0.9804 - recall: 0.9200 - auc: 0.9802 - val_loss: 0.1613 - val_accuracy: 0.9396 - val_precision: 0.9599 - val_recall: 0.9587 - val_auc: 0.9833 - lr: 6.2500e-06
# Epoch 20/20
# Epoch 20/20
# 131/131 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9303 - precision: 0.9835 - recall: 0.9216 - auc: 0.9822
# Epoch 20: val_loss did not improve from 0.16134
# 131/131 [==============================] - 45s 342ms/step - loss: 0.1753 - accuracy: 0.9303 - precision: 0.9835 - recall: 0.9216 - auc: 0.9822 - val_loss: 0.2036 - val_accuracy: 0.9367 - val_precision: 0.9890 - val_recall: 0.9252 - val_auc: 0.9864 - lr: 6.2500e-06
#
# ✅ Treinamento do ResNet50 concluído!
#
# Epoch 20: val_loss did not improve from 0.16134
# 131/131 [==============================] - 45s 342ms/step - loss: 0.1753 - accuracy: 0.9303 - precision: 0.9835 - recall: 0.9216 - auc: 0.9822 - val_loss: 0.2036 - val_accuracy: 0.9367 - val_precision: 0.9890 - val_recall: 0.9252 - val_auc: 0.9864 - lr: 6.2500e-06
#
# ✅ Treinamento do ResNet50 concluído!

# %%
# Plotar histórico
print("\n📈 Visualizando histórico de treinamento...\n")
plot_training_history(history_resnet50, save_path=GRAFICOS_DIR / 'resnet50_history.png')
# Out:
# 📈 Visualizando histórico de treinamento...
#
# ✅ Figura salva em: ..\results\graficos\resnet50_history.png
# ✅ Figura salva em: ..\results\graficos\resnet50_history.png

# %%
# Avaliar no conjunto de teste
print("\n📊 Avaliando ResNet50 no conjunto de teste...\n")
results_resnet50 = evaluate_model(model_resnet50, test_generator)
# Out:
# 📊 Avaliando ResNet50 no conjunto de teste...
#
# 🔍 Avaliando modelo no conjunto de teste...
#
# 20/20 [==============================] - 3s 117ms/step
# 20/20 [==============================] - 3s 117ms/step
#
# 📊 Métricas Gerais:
# ==================================================
# Accuracy:  0.8782 (87.82%)
# F1-Score:  0.9045
# AUC-ROC:   0.9296
# ==================================================
#
# 📋 Relatório Detalhado por Classe:
#
#               precision    recall  f1-score   support
#
#       NORMAL     0.8624    0.8034    0.8319       234
#    PNEUMONIA     0.8867    0.9231    0.9045       390
#
#     accuracy                         0.8782       624
#    macro avg     0.8745    0.8632    0.8682       624
# weighted avg     0.8776    0.8782    0.8773       624
#
#
# 📊 Métricas Gerais:
# ==================================================
# Accuracy:  0.8782 (87.82%)
# F1-Score:  0.9045
# AUC-ROC:   0.9296
# ==================================================
#
# 📋 Relatório Detalhado por Classe:
#
#               precision    recall  f1-score   support
#
#       NORMAL     0.8624    0.8034    0.8319       234
#    PNEUMONIA     0.8867    0.9231    0.9045       390
#
#     accuracy                         0.8782       624
#    macro avg     0.8745    0.8632    0.8682       624
# weighted avg     0.8776    0.8782    0.8773       624

# %%
# Plotar matriz de confusão
plot_confusion_matrix(
    results_resnet50['y_true'], 
    results_resnet50['predictions'],
    save_path=GRAFICOS_DIR / 'resnet50_confusion_matrix.png'
)
# Out:
# ✅ Figura salva em: ..\results\graficos\resnet50_confusion_matrix.png
# 📊 Análise da Matriz de Confusão:
# ==================================================
# Verdadeiros Negativos (TN):  188  - Correto: NORMAL como NORMAL
# Falsos Positivos (FP):        46  - Erro: NORMAL como PNEUMONIA
# Falsos Negativos (FN):        30  - Erro: PNEUMONIA como NORMAL ⚠️
# Verdadeiros Positivos (TP):  360  - Correto: PNEUMONIA como PNEUMONIA
# ==================================================
#
# ⚠️ IMPORTANTE: Falsos Negativos são críticos em medicina!
#    Não detectar uma pneumonia real pode ter consequências graves.

# %%
# Plotar curva ROC
plot_roc_curve(
    results_resnet50['y_true'], 
    results_resnet50['predictions_prob'],
    save_path=GRAFICOS_DIR / 'resnet50_roc_curve.png'
)
# Out:
# ✅ Figura salva em: ..\results\graficos\resnet50_roc_curve.png
# 📈 Interpretação da Curva ROC:
# ==================================================
# AUC = 0.9296
#    Excelente capacidade de discriminação! 🌟
# ==================================================

# %% [markdown]
# ---
# # 📊 COMPARAÇÃO FINAL DOS MODELOS
# ---

# %%
# Compilar todos os resultados
all_results = {
    'CNN Simples': results_cnn,
    'VGG16': results_vgg16,
    'ResNet50': results_resnet50
}

# Comparar modelos
print("\n🏆 COMPARAÇÃO DE TODOS OS MODELOS\n")
compare_models_results(all_results)
# Out:
# 🏆 COMPARAÇÃO DE TODOS OS MODELOS
# 📊 Comparação de Modelos:
# ======================================================================
#      Modelo  Accuracy  F1-Score  AUC-ROC
# CNN Simples  0.791667  0.856195 0.953769
#       VGG16  0.625000  0.769231 0.614092
#    ResNet50  0.878205  0.904523 0.929641
# ======================================================================

# %% [markdown]
# ## 🎯 Análise Detalhada dos Resultados

# %%
# Criar tabela comparativa completa
comparison_data = []

for model_name, results in all_results.items():
    from sklearn.metrics import precision_score, recall_score
    
    precision = precision_score(results['y_true'], results['predictions'])
    recall = recall_score(results['y_true'], results['predictions'])
    
    comparison_data.append({
        'Modelo': model_name,
        'Accuracy': f"{results['accuracy']*100:.2f}%",
        'Precision': f"{precision*100:.2f}%",
        'Recall': f"{recall*100:.2f}%",
        'F1-Score': f"{results['f1_score']*100:.2f}%",
        'AUC-ROC': f"{results['auc']:.4f}"
    })

df_comparison = pd.DataFrame(comparison_data)

print("\n📊 TABELA COMPARATIVA DETALHADA")
print("="*80)
print(df_comparison.to_string(index=False))
print("="*80)
# Out:
# 📊 TABELA COMPARATIVA DETALHADA
# ================================================================================
#      Modelo Accuracy Precision  Recall F1-Score AUC-ROC
# CNN Simples   79.17%    75.29%  99.23%   85.62%  0.9538
#       VGG16   62.50%    62.50% 100.00%   76.92%  0.6141
#    ResNet50   87.82%    88.67%  92.31%   90.45%  0.9296
# ================================================================================

# %% [markdown]
# ## 🔍 Interpretação e Recomendações

# %%
# Encontrar melhor modelo por métrica
best_accuracy = max(all_results.items(), key=lambda x: x[1]['accuracy'])
best_f1 = max(all_results.items(), key=lambda x: x[1]['f1_score'])
best_auc = max(all_results.items(), key=lambda x: x[1]['auc'])

print("\n🏆 MELHORES MODELOS POR MÉTRICA:")
print("="*70)
print(f"🎯 Melhor Accuracy:  {best_accuracy[0]} ({best_accuracy[1]['accuracy']*100:.2f}%)")
print(f"🎯 Melhor F1-Score:  {best_f1[0]} ({best_f1[1]['f1_score']:.4f})")
print(f"🎯 Melhor AUC-ROC:   {best_auc[0]} ({best_auc[1]['auc']:.4f})")
print("="*70)

print("\n💡 INTERPRETAÇÃO:")
print("="*70)
print("""
1. ACCURACY (Acurácia):
   - Percentual de acertos geral
   - Pode ser enganosa em datasets desbalanceados
   
2. PRECISION (Precisão):
   - Dos casos que previmos como PNEUMONIA, quantos realmente são?
   - Importante para evitar falsos alarmes
   
3. RECALL (Sensibilidade):
   - Dos casos reais de PNEUMONIA, quantos conseguimos detectar?
   - CRÍTICO em medicina! Não podemos perder casos reais
   
4. F1-SCORE:
   - Média harmônica entre Precision e Recall
   - Boa métrica quando há desbalanceamento
   
5. AUC-ROC:
   - Capacidade do modelo de discriminar entre classes
   - Quanto mais próximo de 1, melhor
""")
print("="*70)

print("\n⚠️ CONSIDERAÇÕES MÉDICAS:")
print("="*70)
print("""
Em aplicações médicas, o RECALL (Sensibilidade) é geralmente mais importante
que a Precision. É melhor ter alguns falsos positivos (dizer que tem pneumonia
quando não tem) do que falsos negativos (não detectar uma pneumonia real).

Um paciente com falso positivo fará exames adicionais e descobrirá que está
bem. Mas um falso negativo pode deixar uma doença sem tratamento.

Por isso, na prática:
- Priorize modelos com ALTO RECALL
- O médico sempre deve ter a palavra final no diagnóstico
- Este sistema é uma ferramenta de APOIO, não substitui o profissional
""")
print("="*70)
# Out:
# 🏆 MELHORES MODELOS POR MÉTRICA:
# ======================================================================
# 🎯 Melhor Accuracy:  ResNet50 (87.82%)
# 🎯 Melhor F1-Score:  ResNet50 (0.9045)
# 🎯 Melhor AUC-ROC:   CNN Simples (0.9538)
# ======================================================================
#
# 💡 INTERPRETAÇÃO:
# ======================================================================
#
# 1. ACCURACY (Acurácia):
#    - Percentual de acertos geral
#    - Pode ser enganosa em datasets desbalanceados
#
# 2. PRECISION (Precisão):
#    - Dos casos que previmos como PNEUMONIA, quantos realmente são?
#    - Importante para evitar falsos alarmes
#
# 3. RECALL (Sensibilidade):
#    - Dos casos reais de PNEUMONIA, quantos conseguimos detectar?
#    - CRÍTICO em medicina! Não podemos perder casos reais
#
# 4. F1-SCORE:
#    - Média harmônica entre Precision e Recall
#    - Boa métrica quando há desbalanceamento
#
# 5. AUC-ROC:
#    - Capacidade do modelo de discriminar entre classes
#    - Quanto mais próximo de 1, melhor
#
# ======================================================================
#
# ⚠️ CONSIDERAÇÕES MÉDICAS:
# ======================================================================
#
# Em aplicações médicas, o RECALL (Sensibilidade) é geralmente mais importante
# que a Precision. É melhor ter alguns falsos positivos (dizer que tem pneumonia
# quando não tem) do que falsos negativos (não detectar uma pneumonia real).
#
# Um paciente com falso positivo fará exames adicionais e descobrirá que está
# bem. Mas um falso negativo pode deixar uma doença sem tratamento.
#
# Por isso, na prática:
# - Priorize modelos com ALTO RECALL
# - O médico sempre deve ter a palavra final no diagnóstico
# - Este sistema é uma ferramenta de APOIO, não substitui o profissional
#
# ======================================================================

# %% [markdown]
# ## 💾 Salvar Resultados Finais

# %%
# Salvar tabela de comparação
csv_path = RESULTS_DIR / 'comparacao_modelos.csv'
df_comparison.to_csv(csv_path, index=False)
print(f"✅ Tabela de comparação salva em: {csv_path}")

# Salvar resumo dos melhores resultados
with open(RESULTS_DIR / 'resumo_resultados.txt', 'w', encoding='utf-8') as f:
    f.write("="*70 + "\n")
    f.write("RESUMO DOS RESULTADOS - DETECÇÃO DE PNEUMONIA\n")
    f.write("="*70 + "\n\n")
    
    f.write("MODELOS TREINADOS:\n")
    f.write(f"1. CNN Simples (Baseline)\n")
    f.write(f"2. VGG16 Transfer Learning\n")
    f.write(f"3. ResNet50 Transfer Learning\n\n")
    
    f.write("="*70 + "\n")
    f.write("MELHORES MODELOS:\n")
    f.write("="*70 + "\n")
    f.write(f"Melhor Accuracy:  {best_accuracy[0]} ({best_accuracy[1]['accuracy']*100:.2f}%)\n")
    f.write(f"Melhor F1-Score:  {best_f1[0]} ({best_f1[1]['f1_score']:.4f})\n")
    f.write(f"Melhor AUC-ROC:   {best_auc[0]} ({best_auc[1]['auc']:.4f})\n")
    f.write("="*70 + "\n\n")
    
    f.write("COMPARAÇÃO COMPLETA:\n\n")
    f.write(df_comparison.to_string(index=False))
    f.write("\n\n" + "="*70 + "\n")

print(f"✅ Resumo salvo em: {RESULTS_DIR / 'resumo_resultados.txt'}")

print("\n" + "="*70)
print("🎉 TREINAMENTO E AVALIAÇÃO CONCLUÍDOS COM SUCESSO!")
print("="*70)
print(f"\n📁 Todos os resultados foram salvos em: {RESULTS_DIR}")
print(f"💾 Modelos salvos em: {MODELS_DIR}")
print(f"📊 Gráficos salvos em: {GRAFICOS_DIR}")
# Out:
# ✅ Tabela de comparação salva em: ..\results\comparacao_modelos.csv
# ✅ Resumo salvo em: ..\results\resumo_resultados.txt
#
# ======================================================================
# 🎉 TREINAMENTO E AVALIAÇÃO CONCLUÍDOS COM SUCESSO!
# ======================================================================
#
# 📁 Todos os resultados foram salvos em: ..\results
# 💾 Modelos salvos em: ..\results\modelos
# 📊 Gráficos salvos em: ..\results\graficos
#
# ✅ Resumo salvo em: ..\results\resumo_resultados.txt
#
# ======================================================================
# 🎉 TREINAMENTO E AVALIAÇÃO CONCLUÍDOS COM SUCESSO!
# ======================================================================
#
# 📁 Todos os resultados foram salvos em: ..\results
# 💾 Modelos salvos em: ..\results\modelos
# 📊 Gráficos salvos em: ..\results\graficos

# %% [markdown]
# ---
# # ✅ Conclusão
#
# Neste notebook, treinamos e avaliamos três modelos diferentes para detecção de pneumonia em raios-X:
#
# 1. **CNN Simples**: Modelo baseline criado do zero
# 2. **VGG16**: Transfer Learning com arquitetura clássica
# 3. **ResNet50**: Transfer Learning com arquitetura moderna
#
# ### 🎓 O que aprendemos:
#
# - Como trabalhar com dados de imagens médicas
# - Técnicas de data augmentation para aumentar o dataset
# - Transfer Learning e como aproveitar modelos pré-treinados
# - Métricas de avaliação apropriadas para problemas médicos
# - Importância de balancear classes e interpretar erros
#
# ### 🚀 Próximos passos sugeridos:
#
# - Testar outras arquiteturas (EfficientNet, DenseNet)
# - Implementar Grad-CAM para visualizar o que o modelo está "olhando"
# - Criar ensemble de modelos
# - Ajustar hiperparâmetros com GridSearch/RandomSearch
# - Deploy do modelo como API REST
